# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from dotenv import load_dotenv
load_dotenv()

import os
import yaml
from crewai import Agent, Task, Crew

# %% [markdown]
# ## Loading Tasks and Agents YAML files

# %%
# Define file paths for YAML configurations
files = {
    'agents': 'config/agents.yaml',
    'tasks': 'config/tasks.yaml'
}

# Load configurations from YAML files
configs = {}
for config_type, file_path in files.items():
    with open(file_path, 'r') as file:
        configs[config_type] = yaml.safe_load(file)

# Assign loaded configurations to specific variables
agents_config = configs['agents']
tasks_config = configs['tasks']

# %% [markdown]
# ## Create Pydantic Models for Structured Output

# %%
from typing import List
from pydantic import BaseModel, Field

class TaskEstimate(BaseModel):
    task_name: str = Field(..., description="Name of the task")
    estimated_time_hours: float = Field(..., description="Estimated time to complete the task in hours")
    required_resources: List[str] = Field(..., description="List of resources required to complete the task")

class Milestone(BaseModel):
    milestone_name: str = Field(..., description="Name of the milestone")
    tasks: List[str] = Field(..., description="List of task IDs associated with this milestone")

class ProjectPlan(BaseModel):
    tasks: List[TaskEstimate] = Field(..., description="List of tasks with their estimates")
    milestones: List[Milestone] = Field(..., description="List of project milestones")

# %% [markdown]
# ## Create Crew, Agents and Tasks

# %%
# Creating Agents
project_planning_agent = Agent(
  config=agents_config['project_planning_agent']
)

estimation_agent = Agent(
  config=agents_config['estimation_agent']
)

resource_allocation_agent = Agent(
  config=agents_config['resource_allocation_agent']
)

# Creating Tasks
task_breakdown = Task(
  config=tasks_config['task_breakdown'],
  agent=project_planning_agent
)

time_resource_estimation = Task(
  config=tasks_config['time_resource_estimation'],
  agent=estimation_agent
)

resource_allocation = Task(
  config=tasks_config['resource_allocation'],
  agent=resource_allocation_agent,
  output_pydantic=ProjectPlan # This is the structured output we want
)

# Creating Crew
crew = Crew(
  agents=[
    project_planning_agent,
    estimation_agent,
    resource_allocation_agent
  ],
  tasks=[
    task_breakdown,
    time_resource_estimation,
    resource_allocation
  ],
  verbose=True
)
# Out:
# WARNING:opentelemetry.trace:Overriding of current TracerProvider is not allowed

# %% [markdown]
# ## Crew's Input

# %%
from IPython.display import display, Markdown

project = 'Website'
industry = 'Technology'
project_objectives = 'Create a website for a small business'
team_members = """
- John Doe (Project Manager)
- Jane Doe (Software Engineer)
- Bob Smith (Designer)
- Alice Johnson (QA Engineer)
- Tom Brown (QA Engineer)
"""
project_requirements = """
- Create a responsive design that works well on desktop and mobile devices
- Implement a modern, visually appealing user interface with a clean look
- Develop a user-friendly navigation system with intuitive menu structure
- Include an "About Us" page highlighting the company's history and values
- Design a "Services" page showcasing the business's offerings with descriptions
- Create a "Contact Us" page with a form and integrated map for communication
- Implement a blog section for sharing industry news and company updates
- Ensure fast loading times and optimize for search engines (SEO)
- Integrate social media links and sharing capabilities
- Include a testimonials section to showcase customer feedback and build trust
"""

# Format the dictionary as Markdown for a better display in Jupyter Lab
formatted_output = f"""
**Project Type:** {project}

**Project Objectives:** {project_objectives}

**Industry:** {industry}

**Team Members:**
{team_members}
**Project Requirements:**
{project_requirements}
"""
# Display the formatted output as Markdown
display(Markdown(formatted_output))
# Out:
# **Project Type:** Website
#
# **Project Objectives:** Create a website for a small business
#
# **Industry:** Technology
#
# **Team Members:**
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
# **Project Requirements:**
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust

# %% [markdown]
# ## Kicking off the Crew

# %%
# The given Python dictionary
inputs = {
  'project_type': project,
  'project_objectives': project_objectives,
  'industry': industry,
  'team_members': team_members,
  'project_requirements': project_requirements
}

# Run the crew
result = crew.kickoff(
  inputs=inputs
)
# Out:
# # Agent: The Ultimate Project Planner
# ## Task: Carefully analyze the project_requirements for the Website project and break them down into individual tasks. Define each task's scope in details, set achievable timelines, and ensure that all depencies are accounted for:
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: The Ultimate Project Planner
# ## Final Answer:
# ### Project Title: Small Business Website Development
#
# **Project Overview:**
# This project aims to develop a responsive and modern website for a small business, designed to enhance user experience, communicate the company's values, showcase its services, and provide a platform for ongoing updates and engagement with customers.
#
# ### Task Breakdown:
#
# 1. **Conduct Project Kickoff and Requirement Gathering**
#    - **Description:** Initiate the project with a meeting to gather detailed requirements from stakeholders.
#    - **Scope:** Define project goals, user personas, target audience, and any specific features desired for the site.
#    - **Responsible:** John Doe
#    - **Timeline:** Week 1
#    - **Deliverables:** Documented project requirements
#    - **Dependencies:** None
#
# 2. **Create Wireframes and Mockups**
#    - **Description:** Develop wireframes for key pages and design mockups for approval.
#    - **Scope:** Visual layout of the homepage, service page, about us page, contact page, blog, and testimonials section.
#    - **Responsible:** Bob Smith
#    - **Timeline:** Weeks 2-3
#    - **Deliverables:** Approved wireframes and mockups
#    - **Dependencies:** Task 1
#
# 3. **Develop Responsive Design**
#    - **Description:** Implement a responsive design based on approved mockups, ensuring compatibility with desktop and mobile devices.
#    - **Scope:** CSS styling, grid layouts, and media queries.
#    - **Responsible:** Jane Doe
#    - **Timeline:** Weeks 4-5
#    - **Deliverables:** Responsive website design files
#    - **Dependencies:** Task 2
#
# 4. **Build User-Friendly Navigation System**
#    - **Description:** Create an intuitive menu structure for easy content access.
#    - **Scope:** Main navigation bar, dropdowns for services, and footer links.
#    - **Responsible:** Jane Doe
#    - **Timeline:** Week 6
#    - **Deliverables:** Navigation system integrated into the site
#    - **Dependencies:** Task 3
#
# 5. **Develop Key Website Pages**
#    - **Description:** Create the following pages:
#      - About Us
#      - Services
#      - Contact Us
#      - Blog
#      - Testimonials
#    - **Scope:** Content development, layout design, and integration with the navigation.
#    - **Responsible:** Jane Doe
#    - **Timeline:** Weeks 7-10
#    - **Deliverables:** Fully functional pages
#    - **Dependencies:** Task 3
#
# 6. **Integrate Map and Contact Form on "Contact Us" Page**
#    - **Description:** Implement a contact form with validation and a responsive map.
#    - **Scope:** Design form fields, integrate with backend for submissions, and include Google Maps.
#    - **Responsible:** Jane Doe
#    - **Timeline:** Week 11
#    - **Deliverables:** Active contact form and integrated map
#    - **Dependencies:** Task 5
#
# 7. **Implement SEO Optimization and Performance Tuning**
#    - **Description:** Optimize website loading speed and ensure proper SEO practices.
#    - **Scope:** Image compression, meta tags, alt texts, and site structure.
#    - **Responsible:** Jane Doe
#    - **Timeline:** Week 12
#    - **Deliverables:** Optimized website ready for launch
#    - **Dependencies:** Task 5
#
# 8. **Integration of Social Media Links and Sharing Features**
#    - **Description:** Add social media icons and sharing functionality across relevant pages.
#    - **Scope:** Icons for social media platforms; link functionality for blog posts.
#    - **Responsible:** Jane Doe
#    - **Timeline:** Week 13
#    - **Deliverables:** Integrated social media features
#    - **Dependencies:** Task 7
#
# 9. **Quality Assurance Testing**
#    - **Description:** Conduct thorough testing for usability, performance, and bugs.
#    - **Scope:** Test all website functionality across different devices and browsers.
#    - **Responsible:** Alice Johnson, Tom Brown
#    - **Timeline:** Weeks 14-15
#    - **Deliverables:** QA report with identified issues and fixes
#    - **Dependencies:** Tasks 6-8
#
# 10. **Launch Website**
#     - **Description:** Finalize any last-minute adjustments and launch the site.
#     - **Scope:** Deployment to production, final checks on responsiveness and functionality.
#     - **Responsible:** John Doe, Jane Doe
#     - **Timeline:** Week 16
#     - **Deliverables:** Live website
#     - **Dependencies:** Task 9
#
# 11. **Post-launch Support and Feedback Collection**
#     - **Description:** Monitor website performance, collect user feedback, and make necessary adjustments.
#     - **Scope:** Analyze user behavior, gather analytics, and conduct follow-up meetings.
#     - **Responsible:** John Doe, Jane Doe
#     - **Timeline:** Weeks 17-18
#     - **Deliverables:** Feedback report and adjustment list
#     - **Dependencies:** Task 10
#
# ### Gantt Chart Timeline Visualization:
#
# ```
# | Task                                                                               | Week 1 | Week 2 | Week 3 | Week 4 | Week 5 | Week 6 | Week 7 | Week 8 | Week 9 | Week 10 | Week 11 | Week 12 | Week 13 | Week 14 | Week 15 | Week 16 | Week 17 | Week 18 |
# |------------------------------------------------------------------------------------|--------|--------|--------|--------|--------|--------|--------|--------|--------|---------|---------|---------|---------|---------|---------|---------|---------|---------|
# | 1. Project Kickoff and Requirement Gathering                                        |███████ |        |        |        |        |        |        |        |        |         |         |         |         |         |         |         |         |         |
# | 2. Create Wireframes and Mockups                                                   |        |███████ |███████ |        |        |        |        |        |        |         |         |         |         |         |         |         |         |         |
# | 3. Develop Responsive Design                                                         |        |        |        |███████ |███████ |        |        |        |        |         |         |         |         |         |         |         |         |         |
# | 4. Build User-Friendly Navigation System                                             |        |        |        |        |        |███████ |        |        |        |         |         |         |         |         |         |         |         |         |
# | 5. Develop Key Website Pages                                                         |        |        |        |        |        |        |███████ |███████ |███████ |████████ |         |         |         |         |         |         |         |         |
# | 6. Integrate Map and Contact Form on Contact Us Page                                |        |        |        |        |        |        |        |        |        |         |███████ |         |         |         |         |         |         |         |
# | 7. Implement SEO Optimization and Performance Tuning                                 |        |        |        |        |        |        |        |        |        |         |         |███████ |         |         |         |         |         |         |
# | 8. Integration of Social Media Links and Sharing Features                           |        |        |        |        |        |        |        |        |        |         |         |         |███████ |         |         |         |         |         |
# | 9. Quality Assurance Testing                                                          |        |        |        |        |        |        |        |        |        |         |         |         |         |███████ |███████ |         |         |         |
# | 10. Launch Website                                                                     |        |        |        |        |        |        |        |        |        |         |         |         |         |         |         |████████ |         |         |
# | 11. Post-launch Support and Feedback Collection                                       |        |        |        |        |        |        |        |        |        |         |         |         |         |         |         |         |███████ |███████ |
#
# ```
#
# ### Conclusion:
# With the detailed breakdown of tasks, responsibilities, timelines, and dependencies, the Website project is poised for successful execution. This plan ensures no detail is overlooked and systematically guides the project from conception through to post-launch support. Each team member has clearly defined roles, promoting accountability and collaboration.
#
#
# # Agent: Expert Estimation Analyst
# ## Task: Thoroughly evaluate each task in the Website project to estimate the time, resources, and effort required. Use historical data, task complexity, and available resources to provide a realistic estimation for each task.
#
#
#
# # Agent: Expert Estimation Analyst
# ## Final Answer:
# ### Detailed Estimation Report for Small Business Website Development
#
# **Project Title:** Small Business Website Development
# **Project Overview:** This project involves creating a modern, responsive website tailored for a small business to facilitate user engagement and showcase the company's services effectively.
#
# ---
#
# ### Task Breakdown & Estimations
#
# 1. **Conduct Project Kickoff and Requirement Gathering**
#    - **Estimated Time:** 10 hours
#    - **Resources Required:** 1 Project Manager (John Doe)
#    - **Effort:** Low complexity, minimal risk as it sets the groundwork.
#    - **Dependencies:** None
#    - **Deliverables:** Documented project requirements
#
# 2. **Create Wireframes and Mockups**
#    - **Estimated Time:** 40 hours
#    - **Resources Required:** 1 UI/UX Designer (Bob Smith)
#    - **Effort:** Medium complexity, risk if stakeholder feedback is delayed.
#    - **Dependencies:** Task 1
#    - **Deliverables:** Approved wireframes and mockups
#
# 3. **Develop Responsive Design**
#    - **Estimated Time:** 80 hours
#    - **Resources Required:** 1 Front-end Developer (Jane Doe), potential assistance from UI/UX
#    - **Effort:** Medium to high complexity due to cross-device compatibility.
#    - **Dependencies:** Task 2
#    - **Deliverables:** Responsive website design files
#
# 4. **Build User-Friendly Navigation System**
#    - **Estimated Time:** 20 hours
#    - **Resources Required:** 1 Front-end Developer (Jane Doe)
#    - **Effort:** Low complexity, critical to user experience with minimal risk.
#    - **Dependencies:** Task 3
#    - **Deliverables:** Navigation system integrated into the site
#
# 5. **Develop Key Website Pages**
#    - **Estimated Time:** 100 hours
#    - **Resources Required:** 1 Front-end Developer (Jane Doe; potential cross-collaboration with a Content Writer)
#    - **Effort:** Medium complexity, need for rich content integration increases risk if content is not ready.
#    - **Dependencies:** Task 3
#    - **Deliverables:** Fully functional pages
#
# 6. **Integrate Map and Contact Form on "Contact Us" Page**
#    - **Estimated Time:** 20 hours
#    - **Resources Required:** 1 Front-end Developer (Jane Doe), Backend Developer for integration
#    - **Effort:** Medium complexity; possible delays if backend issues arise.
#    - **Dependencies:** Task 5
#    - **Deliverables:** Active contact form and integrated map
#
# 7. **Implement SEO Optimization and Performance Tuning**
#    - **Estimated Time:** 30 hours
#    - **Resources Required:** 1 Front-end Developer (Jane Doe), SEO Specialist
#    - **Effort:** Medium complexity; high importance for site visibility.
#    - **Dependencies:** Task 5
#    - **Deliverables:** Optimized website ready for launch
#
# 8. **Integration of Social Media Links and Sharing Features**
#    - **Estimated Time:** 10 hours
#    - **Resources Required:** 1 Front-end Developer (Jane Doe)
#    - **Effort:** Low complexity, minimal risk.
#    - **Dependencies:** Task 7
#    - **Deliverables:** Integrated social media features
#
# 9. **Quality Assurance Testing**
#    - **Estimated Time:** 60 hours
#    - **Resources Required:** 2 QA Testers (Alice Johnson, Tom Brown)
#    - **Effort:** Medium to high complexity, required thoroughness to ensure functionality.
#    - **Dependencies:** Tasks 6-8
#    - **Deliverables:** QA report with identified issues and fixes
#
# 10. **Launch Website**
#     - **Estimated Time:** 15 hours
#     - **Resources Required:** 1 Project Manager (John Doe), 1 Front-end Developer (Jane Doe)
#     - **Effort:** Medium complexity; high risk if any last-minute issues arise.
#     - **Dependencies:** Task 9
#     - **Deliverables:** Live website
#
# 11. **Post-launch Support and Feedback Collection**
#     - **Estimated Time:** 30 hours
#     - **Resources Required:** 1 Project Manager (John Doe), 1 Front-end Developer (Jane Doe)
#     - **Effort:** Low complexity, time-consuming to analyze feedback effectively.
#     - **Dependencies:** Task 10
#     - **Deliverables:** Feedback report and adjustment list
#
# ---
#
# ### Summary of Risks and Uncertainties
# - **Stakeholder Feedback Delays:** Any delay in approvals can extend timelines significantly, particularly during wireframe and mockup phases.
# - **Content Readiness:** The risk of not having content ready for the pages could hinder development and integration.
# - **Complexity of Features:** Integrating complex features (like contact forms) may uncover unforeseen issues, requiring adjustments to timelines.
# - **Resource Availability:** If a responsible team member becomes unavailable, task timelines may be impacted.
#
# ---
#
# ### Conclusion
# The detailed breakdown of tasks, timelines, resources and risks ensures a comprehensive approach to the successful execution of the Small Business Website Development project. Each task is planned with careful consideration for dependencies and necessary resources to mitigate delays and control budget overruns. The foundation laid during the project kickoff serves as a strong ground for ongoing development and stakeholder satisfaction.
#
# By adhering to this plan, the project is positioned to achieve its objectives efficiently and on budget.
#
#
# # Agent: Resource Allocation Strategist
# ## Task: Strategically allocate tasks for the Website project to team members based on thier skills, availabilty, and current workload. Ensure that each task is assigned to the most suitable team member and that the workload is evenly distributed.
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: Resource Allocation Strategist
# ## Final Answer:
# {
#   "tasks": [
#     {
#       "task_name": "Conduct Project Kickoff and Requirement Gathering",
#       "estimated_time_hours": 10,
#       "required_resources": ["John Doe"]
#     },
#     {
#       "task_name": "Create Wireframes and Mockups",
#       "estimated_time_hours": 40,
#       "required_resources": ["Bob Smith"]
#     },
#     {
#       "task_name": "Develop Responsive Design",
#       "estimated_time_hours": 80,
#       "required_resources": ["Jane Doe"]
#     },
#     {
#       "task_name": "Build User-Friendly Navigation System",
#       "estimated_time_hours": 20,
#       "required_resources": ["Jane Doe"]
#     },
#     {
#       "task_name": "Develop Key Website Pages",
#       "estimated_time_hours": 100,
#       "required_resources": ["Jane Doe"]
#     },
#     {
#       "task_name": "Integrate Map and Contact Form on 'Contact Us' Page",
#       "estimated_time_hours": 20,
#       "required_resources": ["Jane Doe"]
#     },
#     {
#       "task_name": "Implement SEO Optimization and Performance Tuning",
#       "estimated_time_hours": 30,
#       "required_resources": ["Jane Doe"]
#     },
#     {
#       "task_name": "Integration of Social Media Links and Sharing Features",
#       "estimated_time_hours": 10,
#       "required_resources": ["Jane Doe"]
#     },
#     {
#       "task_name": "Quality Assurance Testing",
#       "estimated_time_hours": 60,
#       "required_resources": ["Alice Johnson", "Tom Brown"]
#     },
#     {
#       "task_name": "Launch Website",
#       "estimated_time_hours": 15,
#       "required_resources": ["John Doe", "Jane Doe"]
#     },
#     {
#       "task_name": "Post-launch Support and Feedback Collection",
#       "estimated_time_hours": 30,
#       "required_resources": ["John Doe", "Jane Doe"]
#     }
#   ],
#   "milestones": [
#     {
#       "milestone_name": "Phase 1: Project Kickoff and Planning",
#       "tasks": [
#         "Conduct Project Kickoff and Requirement Gathering"
#       ]
#     },
#     {
#       "milestone_name": "Phase 2: Design",
#       "tasks": [
#         "Create Wireframes and Mockups"
#       ]
#     },
#     {
#       "milestone_name": "Phase 3: Development",
#       "tasks": [
#         "Develop Responsive Design",
#         "Build User-Friendly Navigation System",
#         "Develop Key Website Pages",
#         "Integrate Map and Contact Form on 'Contact Us' Page",
#         "Implement SEO Optimization and Performance Tuning",
#         "Integration of Social Media Links and Sharing Features"
#       ]
#     },
#     {
#       "milestone_name": "Phase 4: Testing",
#       "tasks": [
#         "Quality Assurance Testing"
#       ]
#     },
#     {
#       "milestone_name": "Phase 5: Launch",
#       "tasks": [
#         "Launch Website"
#       ]
#     },
#     {
#       "milestone_name": "Phase 6: Post-Launch",
#       "tasks": [
#         "Post-launch Support and Feedback Collection"
#       ]
#     }
#   ]
# }
