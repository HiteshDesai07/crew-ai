# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from dotenv import load_dotenv

import os
import yaml
from crewai import Agent, Task, Crew

# %%
load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ## Loading Tasks and Agents YAML files

# %%
# Define file paths for YAML configurations
files = {
    'agents': 'config/agents.yaml',
    'tasks': 'config/tasks.yaml'
}

# Load configurations from YAML files
configs = {}
for config_type, file_path in files.items():
    with open(file_path, 'r') as file:
        configs[config_type] = yaml.safe_load(file)

# Assign loaded configurations to specific variables
agents_config = configs['agents']
tasks_config = configs['tasks']

# %% [markdown]
# ## Create Pydantic Models for Structured Output

# %%
from typing import List
from pydantic import BaseModel, Field

class TaskEstimate(BaseModel):
    task_name: str = Field(..., description="Name of the task")
    estimated_time_hours: float = Field(..., description="Estimated time to complete the task in hours")
    required_resources: List[str] = Field(..., description="List of resources required to complete the task")

class Milestone(BaseModel):
    milestone_name: str = Field(..., description="Name of the milestone")
    tasks: List[str] = Field(..., description="List of task IDs associated with this milestone")

class ProjectPlan(BaseModel):
    tasks: List[TaskEstimate] = Field(..., description="List of tasks with their estimates")
    milestones: List[Milestone] = Field(..., description="List of project milestones")

# %% [markdown]
# ## Create Crew, Agents and Tasks

# %%
# Creating Agents
project_planning_agent = Agent(
  config=agents_config['project_planning_agent']
)

estimation_agent = Agent(
  config=agents_config['estimation_agent']
)

resource_allocation_agent = Agent(
  config=agents_config['resource_allocation_agent']
)

# Creating Tasks
task_breakdown = Task(
  config=tasks_config['task_breakdown'],
  agent=project_planning_agent
)

time_resource_estimation = Task(
  config=tasks_config['time_resource_estimation'],
  agent=estimation_agent
)

resource_allocation = Task(
  config=tasks_config['resource_allocation'],
  agent=resource_allocation_agent,
  output_pydantic=ProjectPlan # This is the structured output we want
)

# Creating Crew
crew = Crew(
  agents=[
    project_planning_agent,
    estimation_agent,
    resource_allocation_agent
  ],
  tasks=[
    task_breakdown,
    time_resource_estimation,
    resource_allocation
  ],
  verbose=True
)
# Out:
# WARNING:opentelemetry.trace:Overriding of current TracerProvider is not allowed

# %% [markdown]
# ## Crew's Input

# %%
from IPython.display import display, Markdown

project = 'Website'
industry = 'Technology'
project_objectives = 'Create a website for a small business'
team_members = """
- John Doe (Project Manager)
- Jane Doe (Software Engineer)
- Bob Smith (Designer)
- Alice Johnson (QA Engineer)
- Tom Brown (QA Engineer)
"""
project_requirements = """
- Create a responsive design that works well on desktop and mobile devices
- Implement a modern, visually appealing user interface with a clean look
- Develop a user-friendly navigation system with intuitive menu structure
- Include an "About Us" page highlighting the company's history and values
- Design a "Services" page showcasing the business's offerings with descriptions
- Create a "Contact Us" page with a form and integrated map for communication
- Implement a blog section for sharing industry news and company updates
- Ensure fast loading times and optimize for search engines (SEO)
- Integrate social media links and sharing capabilities
- Include a testimonials section to showcase customer feedback and build trust
"""

# Format the dictionary as Markdown for a better display in Jupyter Lab
formatted_output = f"""
**Project Type:** {project}

**Project Objectives:** {project_objectives}

**Industry:** {industry}

**Team Members:**
{team_members}
**Project Requirements:**
{project_requirements}
"""
# Display the formatted output as Markdown
display(Markdown(formatted_output))
# Out:
# **Project Type:** Website
#
# **Project Objectives:** Create a website for a small business
#
# **Industry:** Technology
#
# **Team Members:**
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
# **Project Requirements:**
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust

# %% [markdown]
# ## Kicking off the Crew

# %%
# The given Python dictionary
inputs = {
  'project_type': project,
  'project_objectives': project_objectives,
  'industry': industry,
  'team_members': team_members,
  'project_requirements': project_requirements
}

# Run the crew
result = crew.kickoff(
  inputs=inputs
)
# Out:
# # Agent: The Ultimate Project Planner
# ## Task: Carefully analyze the project_requirements for the Website project and break them down into individual tasks. Define each task's scope in details, set achievable timelines, and ensure that all depencies are accounted for:
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: The Ultimate Project Planner
# ## Final Answer:
# ### Project Breakdown for the Website Project
#
# **1. Project Overview:**
#    - **Goal:** Create a small business website that is responsive, visually appealing, and user-friendly.
#    - **Timeline:** 12 weeks
#    - **Team Members:**
#      - John Doe (Project Manager)
#      - Jane Doe (Software Engineer)
#      - Bob Smith (Designer)
#      - Alice Johnson (QA Engineer)
#      - Tom Brown (QA Engineer)
#
# ---
#
# #### Comprehensive List of Tasks
#
# | Task ID | Task Description                                                         | Owner         | Duration | Dependency         | Deliverable                                               |
# |---------|-------------------------------------------------------------------------|---------------|----------|---------------------|-----------------------------------------------------------|
# | 1       | Project Kick-off and Requirement Gathering                              | John Doe      | 1 week   | None                | Kick-off meeting notes, requirement document               |
# | 2       | Create Wireframes and Design Mockups for all Pages                     | Bob Smith     | 2 weeks  | 1                   | Completed wireframes and mockups                          |
# | 3       | Create a Responsive Design (Desktop & Mobile)                          | Bob Smith     | 2 weeks  | 2                   | Responsive design assets                                   |
# | 4       | Develop User Interface with Modern Aesthetics                          | Jane Doe      | 3 weeks  | 3                   | Completed front-end design implementation                   |
# | 5       | Implement Navigation System with Intuitive Menu Structure              | Jane Doe      | 1 week   | 4                   | Live navigation structure                                   |
# | 6       | Design "About Us" Page                                                 | Bob Smith     | 1 week   | 5                   | Completed "About Us" page                                  |
# | 7       | Design "Services" Page with Descriptions                                | Bob Smith     | 1 week   | 5                   | Completed "Services" page                                  |
# | 8       | Create "Contact Us" Page with Form and Map Integration                 | Jane Doe      | 1 week   | 4                   | Completed "Contact Us" page                                |
# | 9       | Implement Blog Section                                                  | Jane Doe      | 2 weeks  | 4                   | Functional blog section                                    |
# | 10      | Ensure Fast Loading Times and Optimize for Search Engines (SEO)        | Jane Doe      | 1 week   | 4                   | SEO optimization report and performance metrics            |
# | 11      | Integrate Social Media Links and Sharing Capabilities                   | Jane Doe      | 1 week   | 4                   | Working social media integration                            |
# | 12      | Design Testimonials Section                                              | Bob Smith     | 1 week   | 4                   | Completed testimonials section                              |
# | 13      | Internal Quality Assurance Testing                                       | Alice Johnson & Tom Brown | 2 weeks  | 4-12                | QA report with identified issues and fixed list            |
# | 14      | Final Review and Revisions Based on QA Feedback                        | All Team Members | 1 week   | 13                  | Final adjustments and testing completed                    |
# | 15      | Launch the Website and Monitor Post-Launch Performance                  | All Team Members | 1 week   | 14                  | Live website and post-launch performance report            |
#
# #### Gantt Chart Visualization
#
# ```plaintext
# | Task ID | Task Description                    | Week 1 | Week 2 | Week 3 | Week 4 | Week 5 | Week 6 | Week 7 | Week 8 | Week 9 | Week 10 | Week 11 | Week 12 |
# |---------|-------------------------------------|--------|--------|--------|--------|--------|--------|--------|--------|--------|---------|---------|---------|
# | 1       | Project Kick-off                   |████████|        |        |        |        |        |        |        |        |         |         |         |
# | 2       | Wireframes & Mockups               |        |████████|████████|        |        |        |        |        |        |         |         |         |
# | 3       | Responsive Design                   |        |        |████████|████████|        |        |        |        |        |         |         |         |
# | 4       | UI Development                      |        |        |        |████████|████████|        |        |        |        |         |         |         |
# | 5       | Navigation System                   |        |        |        |        |████████|        |        |        |        |         |         |         |
# | 6       | "About Us" Page                    |        |        |        |        |        |████████|        |        |        |         |         |         |
# | 7       | "Services" Page                    |        |        |        |        |        |        |████████|        |        |         |         |         |
# | 8       | "Contact Us" Page                  |        |        |        |        |        |        |        |████████|        |         |         |         |
# | 9       | Blog Section                        |        |        |        |        |        |        |        |        |████████|████████|         |         |
# | 10      | SEO Optimization                    |        |        |        |        |        |        |        |        |        |████████|         |         |
# | 11      | Social Media Integration            |        |        |        |        |        |        |        |        |        |         |████████|         |
# | 12      | Testimonials Section                |        |        |        |        |        |        |        |        |        |         |         |████████|
# | 13      | QA Testing                          |        |        |        |        |        |        |        |        |        |         |         |████████|
# | 14      | Final Review                        |        |        |        |        |        |        |        |        |        |         |         |         |
# | 15      | Launch                              |        |        |        |        |        |        |        |        |        |         |         |         |
# ```
#
# ### Conclusion
# This detailed breakdown ensures that every aspect of the website construction is carefully planned out, with clear timelines and responsibilities assigned to each team member. The Gantt chart visualizes the project timeline, giving a clear overview of task dependencies, ensuring we meet our goal of delivering a high-quality website on time and within scope.
#
#
# # Agent: Expert Estimation Analyst
# ## Task: Thoroughly evaluate each task in the Website project to estimate the time, resources, and effort required. Use historical data, task complexity, and available resources to provide a realistic estimation for each task.
#
#
#
# # Agent: Expert Estimation Analyst
# ## Final Answer:
# ### Detailed Estimation Report for Website Project
#
# #### Introduction
# This estimation report evaluates each task within the Website project to provide realistic estimates of time, resources, and effort required for successful completion. We will also discuss potential risks and uncertainties associated with these estimations.
#
# ---
#
# ### Task Breakdown
#
# | Task ID | Task Description                                                         | Owner         | Estimated Duration | Resources Required             | Total Effort (Person-Hours) | Risks & Uncertainties                                              |
# |---------|-------------------------------------------------------------------------|---------------|--------------------|--------------------------------|------------------------------|--------------------------------------------------------------------|
# | 1       | Project Kick-off and Requirement Gathering                              | John Doe      | 1 week             | 5 hours (PM)                  | 5                            | Misunderstood requirements due to unclear stakeholder input.       |
# | 2       | Create Wireframes and Design Mockups for all Pages                     | Bob Smith     | 2 weeks            | 30 hours (Designer)           | 60                           | Design feedback could delay completion; reliance on client feedback. |
# | 3       | Create a Responsive Design (Desktop & Mobile)                          | Bob Smith     | 2 weeks            | 20 hours (Designer)           | 40                           | Device testing may take longer than anticipated, impacting timeframe. |
# | 4       | Develop User Interface with Modern Aesthetics                          | Jane Doe      | 3 weeks            | 45 hours (Developer)          | 135                          | Complexity of UI may result in unforeseen coding challenges.        |
# | 5       | Implement Navigation System with Intuitive Menu Structure              | Jane Doe      | 1 week             | 20 hours (Developer)          | 20                           | Changes in project scope during implementation may require rework.  |
# | 6       | Design "About Us" Page                                                 | Bob Smith     | 1 week             | 10 hours (Designer)           | 10                           | Content approvals could be delayed.                                |
# | 7       | Design "Services" Page with Descriptions                                | Bob Smith     | 1 week             | 10 hours (Designer)           | 10                           | Potential need for revisions based on client feedback.             |
# | 8       | Create "Contact Us" Page with Form and Map Integration                 | Jane Doe      | 1 week             | 15 hours (Developer)          | 15                           | Geo-location services may have compatibility issues.               |
# | 9       | Implement Blog Section                                                  | Jane Doe      | 2 weeks            | 30 hours (Developer)          | 60                           | Integration with existing systems might lead to technical blockers. |
# | 10      | Ensure Fast Loading Times and Optimize for Search Engines (SEO)        | Jane Doe      | 1 week             | 10 hours (Developer)          | 10                           | Unexpected technical adjustments may affect timelines.              |
# | 11      | Integrate Social Media Links and Sharing Capabilities                   | Jane Doe      | 1 week             | 10 hours (Developer)          | 10                           | Changes in social media APIs could impact integration.              |
# | 12      | Design Testimonials Section                                              | Bob Smith     | 1 week             | 10 hours (Designer)           | 10                           | Client feedback on content could delay the design process.         |
# | 13      | Internal Quality Assurance Testing                                       | Alice Johnson & Tom Brown | 2 weeks  | 20 hours (QA) per engineer   | 80                           | Undiscovered bugs may re-enter previous tasks for fixes.           |
# | 14      | Final Review and Revisions Based on QA Feedback                        | All Team Members | 1 week           | 15 hours (All Members)        | 15                           | Feedback could result in significant last-minute changes.         |
# | 15      | Launch the Website and Monitor Post-Launch Performance                  | All Team Members | 1 week           | 20 hours (All Members)        | 20                           | Unforeseen bugs could emerge post-launch affecting user experience. |
#
# #### Total Summary of Time, Resources, and Effort:
#
# - **Total Estimated Duration:** 12 Weeks
# - **Total Resources Required:**
#   - Project Manager: 5 Hours
#   - Designers: 80 Hours (30 + 20 + 10 +10 +10)
#   - Developers: 115 Hours (45 + 20 + 15 + 30 + 10)
#   - QA Engineers: 40 Hours (20 + 20)
#   - All Team Members: 35 Hours (15 for review and 20 for launch)
# - **Total Estimated Effort:** 375 Person-Hours
#
# ---
#
# ### Risks and Uncertainties
# 1. **Dependency on Stakeholder Feedback:** Delays in receiving feedback can push timelines back significantly, affecting consecutive tasks.
# 2. **Technical Challenges:** As complexity increases, unforeseen technical issues may arise which could extend development times.
# 3. **Resource Availability:** The project timeline assumes all team members are available as planned; changes in personnel can raise effort and duration.
# 4. **Integration Issues:** When connecting various platforms or tools, unexpected incompatibilities can lead to additional effort.
#
# ---
#
# ### Conclusion
# This detailed estimation report outlines the necessary time, resources, and effort required for each task in the Website project while considering inherent risks. Tracking progress against these estimations is crucial for maintaining the project timeline and budget, ensuring effective project management practices.
#
# This estimation ensures a structured and efficient approach to project execution, aiming for a high-quality delivery that meets the client’s expectations within the stipulated timelines.
#
#
# # Agent: Resource Allocation Strategist
# ## Task: Strategically allocate tasks for the Website project to team members based on thier skills, availabilty, and current workload. Ensure that each task is assigned to the most suitable team member and that the workload is evenly distributed.
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: Resource Allocation Strategist
# ## Final Answer:
# {
#   "tasks": [
#     {
#       "task_name": "Project Kick-off and Requirement Gathering",
#       "estimated_time_hours": 5,
#       "required_resources": ["John Doe"]
#     },
#     {
#       "task_name": "Create Wireframes and Design Mockups for all Pages",
#       "estimated_time_hours": 60,
#       "required_resources": ["Bob Smith"]
#     },
#     {
#       "task_name": "Create a Responsive Design (Desktop & Mobile)",
#       "estimated_time_hours": 40,
#       "required_resources": ["Bob Smith"]
#     },
#     {
#       "task_name": "Develop User Interface with Modern Aesthetics",
#       "estimated_time_hours": 135,
#       "required_resources": ["Jane Doe"]
#     },
#     {
#       "task_name": "Implement Navigation System with Intuitive Menu Structure",
#       "estimated_time_hours": 20,
#       "required_resources": ["Jane Doe"]
#     },
#     {
#       "task_name": "Design 'About Us' Page",
#       "estimated_time_hours": 10,
#       "required_resources": ["Bob Smith"]
#     },
#     {
#       "task_name": "Design 'Services' Page with Descriptions",
#       "estimated_time_hours": 10,
#       "required_resources": ["Bob Smith"]
#     },
#     {
#       "task_name": "Create 'Contact Us' Page with Form and Map Integration",
#       "estimated_time_hours": 15,
#       "required_resources": ["Jane Doe"]
#     },
#     {
#       "task_name": "Implement Blog Section",
#       "estimated_time_hours": 60,
#       "required_resources": ["Jane Doe"]
#     },
#     {
#       "task_name": "Ensure Fast Loading Times and Optimize for Search Engines (SEO)",
#       "estimated_time_hours": 10,
#       "required_resources": ["Jane Doe"]
#     },
#     {
#       "task_name": "Integrate Social Media Links and Sharing Capabilities",
#       "estimated_time_hours": 10,
#       "required_resources": ["Jane Doe"]
#     },
#     {
#       "task_name": "Design Testimonials Section",
#       "estimated_time_hours": 10,
#       "required_resources": ["Bob Smith"]
#     },
#     {
#       "task_name": "Internal Quality Assurance Testing",
#       "estimated_time_hours": 40,
#       "required_resources": ["Alice Johnson", "Tom Brown"]
#     },
#     {
#       "task_name": "Final Review and Revisions Based on QA Feedback",
#       "estimated_time_hours": 15,
#       "required_resources": ["John Doe", "Jane Doe", "Bob Smith", "Alice Johnson", "Tom Brown"]
#     },
#     {
#       "task_name": "Launch the Website and Monitor Post-Launch Performance",
#       "estimated_time_hours": 20,
#       "required_resources": ["John Doe", "Jane Doe", "Bob Smith", "Alice Johnson", "Tom Brown"]
#     }
#   ],
#   "milestones": [
#     {
#       "milestone_name": "Project Kick-off",
#       "tasks": ["Project Kick-off and Requirement Gathering"]
#     },
#     {
#       "milestone_name": "Design Phase",
#       "tasks": [
#         "Create Wireframes and Design Mockups for all Pages",
#         "Create a Responsive Design (Desktop & Mobile)",
#         "Design 'About Us' Page",
#         "Design 'Services' Page with Descriptions",
#         "Design Testimonials Section"
#       ]
#     },
#     {
#       "milestone_name": "Development Phase",
#       "tasks": [
#         "Develop User Interface with Modern Aesthetics",
#         "Implement Navigation System with Intuitive Menu Structure",
#         "Create 'Contact Us' Page with Form and Map Integration",
#         "Implement Blog Section",
#         "Ensure Fast Loading Times and Optimize for Search Engines (SEO)",
#         "Integrate Social Media Links and Sharing Capabilities"
#       ]
#     },
#     {
#       "milestone_name": "Testing Phase",
#       "tasks": ["Internal Quality Assurance Testing"]
#     },
#     {
#       "milestone_name": "Review Phase",
#       "tasks": ["Final Review and Revisions Based on QA Feedback"]
#     },
#     {
#       "milestone_name": "Launch Phase",
#       "tasks": ["Launch the Website and Monitor Post-Launch Performance"]
#     }
#   ]
# }

# %% [markdown]
# ## Usage Metrics and Costs

# %% [markdown]
# Let's see how much it would cost each time if this crew runs at scale

# %%
import pandas as pd

costs = 0.150 * (crew.usage_metrics.prompt_tokens + crew.usage_metrics.completion_tokens) / 1_000_000
print(f"Total costs: ${costs:.4f}")

# Convert UsageMetrics instance to a DataFrame
df_usage_metrics = pd.DataFrame([crew.usage_metrics.dict()])
df_usage_metrics
# Out:
# Total costs: $0.0011
#    total_tokens  prompt_tokens  cached_prompt_tokens  completion_tokens  \
# 0          7044           3664                     0               3380
#
#    successful_requests
# 0                    3

# %%
result.pydantic.dict()
# Out:
# {'tasks': [{'task_name': 'Project Kick-off and Requirement Gathering',
#    'estimated_time_hours': 5.0,
#    'required_resources': ['John Doe']},
#   {'task_name': 'Create Wireframes and Design Mockups for all Pages',
#    'estimated_time_hours': 60.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'Create a Responsive Design (Desktop & Mobile)',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'Develop User Interface with Modern Aesthetics',
#    'estimated_time_hours': 135.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Implement Navigation System with Intuitive Menu Structure',
#    'estimated_time_hours': 20.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': "Design 'About Us' Page",
#    'estimated_time_hours': 10.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': "Design 'Services' Page with Descriptions",
#    'estimated_time_hours': 10.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': "Create 'Contact Us' Page with Form and Map Integration",
#    'estimated_time_hours': 15.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Implement Blog Section',
#    'estimated_time_hours': 60.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Ensure Fast Loading Times and Optimize for Search Engines (SEO)',
#    'estimated_time_hours': 10.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Integrate Social Media Links and Sharing Capabilities',
#    'estimated_time_hours': 10.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Design Testimonials Section',
#    'estimated_time_hours': 10.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'Internal Quality Assurance Testing',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Alice Johnson', 'Tom Brown']},
#   {'task_name': 'Final Review and Revisions Based on QA Feedback',
#    'estimated_time_hours': 15.0,
#    'required_resources': ['John Doe',
#     'Jane Doe',
#     'Bob Smith',
#     'Alice Johnson',
#     'Tom Brown']},
#   {'task_name': 'Launch the Website and Monitor Post-Launch Performance',
#    'estimated_time_hours': 20.0,
#    'required_resources': ['John Doe',
#     'Jane Doe',
#     'Bob Smith',
#     'Alice Johnson',
#     'Tom Brown']}],
#  'milestones': [{'milestone_name': 'Project Kick-off',
#    'tasks': ['Project Kick-off and Requirement Gathering']},
#   {'milestone_name': 'Design Phase',
#    'tasks': ['Create Wireframes and Design Mockups for all Pages',
#     'Create a Responsive Design (Desktop & Mobile)',
#     "Design 'About Us' Page",
#     "Design 'Services' Page with Descriptions",
#     'Design Testimonials Section']},
#   {'milestone_name': 'Development Phase',
#    'tasks': ['Develop User Interface with Modern Aesthetics',
#     'Implement Navigation System with Intuitive Menu Structure',
#     "Create 'Contact Us' Page with Form and Map Integration",
#     'Implement Blog Section',
#     'Ensure Fast Loading Times and Optimize for Search Engines (SEO)',
#     'Integrate Social Media Links and Sharing Capabilities']},
#   {'milestone_name': 'Testing Phase',
#    'tasks': ['Internal Quality Assurance Testing']},
#   {'milestone_name': 'Review Phase',
#    'tasks': ['Final Review and Revisions Based on QA Feedback']},
#   {'milestone_name': 'Launch Phase',
#    'tasks': ['Launch the Website and Monitor Post-Launch Performance']}]}

# %%
tasks = result.pydantic.dict()['tasks']
df_tasks = pd.DataFrame(tasks)

# Display the DataFrame as an HTML table
df_tasks.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_6141c th {
#   font-size: 120%;
# }
# #T_6141c  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_6141c" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6141c_level0_col0" class="col_heading level0 col0" >task_name</th>
#       <th id="T_6141c_level0_col1" class="col_heading level0 col1" >estimated_time_hours</th>
#       <th id="T_6141c_level0_col2" class="col_heading level0 col2" >required_resources</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6141c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6141c_row0_col0" class="data row0 col0" >Project Kick-off and Requirement Gathering</td>
#       <td id="T_6141c_row0_col1" class="data row0 col1" >5.000000</td>
#       <td id="T_6141c_row0_col2" class="data row0 col2" >['John Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_6141c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6141c_row1_col0" class="data row1 col0" >Create Wireframes and Design Mockups for all Pages</td>
#       <td id="T_6141c_row1_col1" class="data row1 col1" >60.000000</td>
#       <td id="T_6141c_row1_col2" class="data row1 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_6141c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6141c_row2_col0" class="data row2 col0" >Create a Responsive Design (Desktop & Mobile)</td>
#       <td id="T_6141c_row2_col1" class="data row2 col1" >40.000000</td>
#       <td id="T_6141c_row2_col2" class="data row2 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_6141c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6141c_row3_col0" class="data row3 col0" >Develop User Interface with Modern Aesthetics</td>
#       <td id="T_6141c_row3_col1" class="data row3 col1" >135.000000</td>
#       <td id="T_6141c_row3_col2" class="data row3 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_6141c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6141c_row4_col0" class="data row4 col0" >Implement Navigation System with Intuitive Menu Structure</td>
#       <td id="T_6141c_row4_col1" class="data row4 col1" >20.000000</td>
#       <td id="T_6141c_row4_col2" class="data row4 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_6141c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6141c_row5_col0" class="data row5 col0" >Design 'About Us' Page</td>
#       <td id="T_6141c_row5_col1" class="data row5 col1" >10.000000</td>
#       <td id="T_6141c_row5_col2" class="data row5 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_6141c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6141c_row6_col0" class="data row6 col0" >Design 'Services' Page with Descriptions</td>
#       <td id="T_6141c_row6_col1" class="data row6 col1" >10.000000</td>
#       <td id="T_6141c_row6_col2" class="data row6 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_6141c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6141c_row7_col0" class="data row7 col0" >Create 'Contact Us' Page with Form and Map Integration</td>
#       <td id="T_6141c_row7_col1" class="data row7 col1" >15.000000</td>
#       <td id="T_6141c_row7_col2" class="data row7 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_6141c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6141c_row8_col0" class="data row8 col0" >Implement Blog Section</td>
#       <td id="T_6141c_row8_col1" class="data row8 col1" >60.000000</td>
#       <td id="T_6141c_row8_col2" class="data row8 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_6141c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6141c_row9_col0" class="data row9 col0" >Ensure Fast Loading Times and Optimize for Search Engines (SEO)</td>
#       <td id="T_6141c_row9_col1" class="data row9 col1" >10.000000</td>
#       <td id="T_6141c_row9_col2" class="data row9 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_6141c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_6141c_row10_col0" class="data row10 col0" >Integrate Social Media Links and Sharing Capabilities</td>
#       <td id="T_6141c_row10_col1" class="data row10 col1" >10.000000</td>
#       <td id="T_6141c_row10_col2" class="data row10 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_6141c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_6141c_row11_col0" class="data row11 col0" >Design Testimonials Section</td>
#       <td id="T_6141c_row11_col1" class="data row11 col1" >10.000000</td>
#       <td id="T_6141c_row11_col2" class="data row11 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_6141c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_6141c_row12_col0" class="data row12 col0" >Internal Quality Assurance Testing</td>
#       <td id="T_6141c_row12_col1" class="data row12 col1" >40.000000</td>
#       <td id="T_6141c_row12_col2" class="data row12 col2" >['Alice Johnson', 'Tom Brown']</td>
#     </tr>
#     <tr>
#       <th id="T_6141c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_6141c_row13_col0" class="data row13 col0" >Final Review and Revisions Based on QA Feedback</td>
#       <td id="T_6141c_row13_col1" class="data row13 col1" >15.000000</td>
#       <td id="T_6141c_row13_col2" class="data row13 col2" >['John Doe', 'Jane Doe', 'Bob Smith', 'Alice Johnson', 'Tom Brown']</td>
#     </tr>
#     <tr>
#       <th id="T_6141c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_6141c_row14_col0" class="data row14 col0" >Launch the Website and Monitor Post-Launch Performance</td>
#       <td id="T_6141c_row14_col1" class="data row14 col1" >20.000000</td>
#       <td id="T_6141c_row14_col2" class="data row14 col2" >['John Doe', 'Jane Doe', 'Bob Smith', 'Alice Johnson', 'Tom Brown']</td>
#     </tr>
#   </tbody>
# </table>

# %%
milestones = result.pydantic.dict()['milestones']
df_milestones = pd.DataFrame(milestones)

# Display the DataFrame as an HTML table
df_milestones.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_0a3df th {
#   font-size: 120%;
# }
# #T_0a3df  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_0a3df" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0a3df_level0_col0" class="col_heading level0 col0" >milestone_name</th>
#       <th id="T_0a3df_level0_col1" class="col_heading level0 col1" >tasks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0a3df_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0a3df_row0_col0" class="data row0 col0" >Project Kick-off</td>
#       <td id="T_0a3df_row0_col1" class="data row0 col1" >['Project Kick-off and Requirement Gathering']</td>
#     </tr>
#     <tr>
#       <th id="T_0a3df_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0a3df_row1_col0" class="data row1 col0" >Design Phase</td>
#       <td id="T_0a3df_row1_col1" class="data row1 col1" >['Create Wireframes and Design Mockups for all Pages', 'Create a Responsive Design (Desktop & Mobile)', "Design 'About Us' Page", "Design 'Services' Page with Descriptions", 'Design Testimonials Section']</td>
#     </tr>
#     <tr>
#       <th id="T_0a3df_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0a3df_row2_col0" class="data row2 col0" >Development Phase</td>
#       <td id="T_0a3df_row2_col1" class="data row2 col1" >['Develop User Interface with Modern Aesthetics', 'Implement Navigation System with Intuitive Menu Structure', "Create 'Contact Us' Page with Form and Map Integration", 'Implement Blog Section', 'Ensure Fast Loading Times and Optimize for Search Engines (SEO)', 'Integrate Social Media Links and Sharing Capabilities']</td>
#     </tr>
#     <tr>
#       <th id="T_0a3df_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0a3df_row3_col0" class="data row3 col0" >Testing Phase</td>
#       <td id="T_0a3df_row3_col1" class="data row3 col1" >['Internal Quality Assurance Testing']</td>
#     </tr>
#     <tr>
#       <th id="T_0a3df_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0a3df_row4_col0" class="data row4 col0" >Review Phase</td>
#       <td id="T_0a3df_row4_col1" class="data row4 col1" >['Final Review and Revisions Based on QA Feedback']</td>
#     </tr>
#     <tr>
#       <th id="T_0a3df_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0a3df_row5_col0" class="data row5 col0" >Launch Phase</td>
#       <td id="T_0a3df_row5_col1" class="data row5 col1" >['Launch the Website and Monitor Post-Launch Performance']</td>
#     </tr>
#   </tbody>
# </table>
